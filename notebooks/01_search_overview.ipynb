# %% [markdown]
# # 01: Multi-Database Search Overview
#
# Search across all available databases for each research domain.
#
# ## Available MCP Tools
# - `mcp__semantic-scholar__*` - Semantic Scholar (200M+ papers)
# - `mcp__openalex__*` - OpenAlex (250M+ works)
# - `mcp__zotero__*` - Your Zotero library
# - `mcp__paper-search__*` - arXiv, PubMed, bioRxiv, medRxiv

# %%
# Research domains and search terms
RESEARCH_DOMAINS = {
    "pcg": {
        "name": "Procedural Content Generation",
        "terms": ["procedural content generation", "procedural generation games", "PCGML"],
        "years": (2011, 2025),
        "min_citations": 50,
    },
    "llm_npc": {
        "name": "NPCs & Believable Agents",
        "terms": ["generative agents", "LLM NPC", "believable agents games"],
        "years": (2020, 2025),
        "min_citations": 20,
    },
    "text_to_3d": {
        "name": "3D Generation",
        "terms": ["text-to-3D", "DreamFusion", "neural 3D generation", "NeRF"],
        "years": (2020, 2025),
        "min_citations": 50,
    },
    "worldbuilding": {
        "name": "Worldbuilding Theory",
        "terms": ["worldbuilding theory", "subcreation", "imaginary worlds"],
        "years": (2000, 2025),
        "min_citations": 30,
    },
    "neural_worlds": {
        "name": "Generative Interactive Worlds",
        "terms": ["Genie DeepMind", "world models games", "neural game engine"],
        "years": (2023, 2025),
        "min_citations": 10,
    },
}

# %% [markdown]
# ## Instructions for Claude Code
#
# Use the following prompts to search each domain:
#
# ```
# Search Semantic Scholar for the most cited papers on 'procedural content generation' from 2015-2024, limit 20
# ```
#
# ```
# Search OpenAlex for topic trends in 'procedural generation games' from 2015-2025
# ```
#
# ```
# Check my Zotero library for papers related to 'WFC' or 'wave function collapse'
# ```

# %%
# Placeholder for search results
# Claude Code will populate this via MCP tools
search_results = {}
